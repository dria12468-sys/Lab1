# %% [markdown]
# # Lab 2

# %% [markdown]
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/giswqs/gispro-fall26/blob/main/book/labs/lab_02.ipynb)
# [![image](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/giswqs/gispro-fall26/main?urlpath=lab/tree/book/labs/lab_02.ipynb)

# %% [markdown]
# This notebook contains exercises based on the lectures on [**String Operations**](../python/string-operations.md) and [**Looping and Control Statements**](../python/looping.md). These exercises will help reinforce the concepts of string manipulation, loops, and conditionals in geospatial contexts.

# %% [markdown]
# ## Exercise 1: Manipulating Geographic Location Strings
#
# - Create a string that represents the name of a geographic feature (e.g., `"Amazon River"`).
# - Convert the string to lowercase and then to uppercase.
# - Concatenate the string with the name of the country (e.g., `"Brazil"`) to create a full location name.
# - Repeat the string three times, separating each repetition with a dash (`-`).

# %%
geogfeature_name = "Geographic Feature: Grand Canyon"

print(f"Original: {geogfeature_name}")
print(f"Lowercase: {geogfeature_name.lower()}")
print(f"Uppercase: {geogfeature_name.upper()}")

geogfeature_location = geogfeature_name + ", Location: USA"
print(f"{geogfeature_location}")

print(f"Repeated: {' - '.join([geogfeature_location] * 3)}")
# Out:
# Original: Geographic Feature: Grand Canyon
# Lowercase: geographic feature: grand canyon
# Uppercase: GEOGRAPHIC FEATURE: GRAND CANYON
# Geographic Feature: Grand Canyon, Location: USA
# Repeated: Geographic Feature: Grand Canyon, Location: USA - Geographic Feature: Grand Canyon, Location: USA - Geographic Feature: Grand Canyon, Location: USA

# %% [markdown]
# ## Exercise 2: Extracting and Formatting Coordinates
#
# - Given a string with the format `"latitude, longitude"` (e.g., `"40.7128N, 74.0060W"`), extract the numeric values of latitude and longitude.
# - Convert these values to floats and remove the directional indicators (`N`, `S`, `E`, `W`).
# - Format the coordinates into a `POINT` WKT string (e.g., `"POINT(-74.0060 40.7128)"`).

# %%
latitude = "40.7128"
longitude = "74.0060"
coordinates = f"{latitude}N, {longitude}W"
print(coordinates)

latitude_fl = float(latitude)
longitude_fl = float(longitude)
print(f"Latitude={latitude_fl}, Longitude={longitude_fl}")

wkt_point = f"POINT({latitude_fl} {longitude_fl})"
print(wkt_point)
# Out:
# 40.7128N, 74.0060W
# Latitude=40.7128, Longitude=74.006
# POINT(40.7128 74.006)

# %%
latitude_fl = float(latitude)
longitude_fl = float(longitude)
print(f"Latitude={latitude_fl}, Longitude={longitude_fl}")
# Out:
# Latitude=40.7128, Longitude=74.006

# %% [markdown]
# ## Exercise 3: Building Dynamic SQL Queries
#
# - Given a table name and a condition, dynamically build an SQL query string.
# - Example: If `table_name = "cities"` and `condition = "population > 1000000"`, the query should be `"SELECT * FROM cities WHERE population > 1000000;"`.
# - Add additional conditions dynamically, like `AND` clauses.

# %%
table_name = "cities"
condition = "population > 1000000"

query = f"SELECT * FROM {table_name} WHERE {condition};"
print(query)
# Out:
# SELECT NAME FROM cities WHERE population > 1000000;

# %% [markdown]
# ## Exercise 4: String Normalization and Cleaning
#
# - Given a list of city names with inconsistent formatting (e.g., `[" new york ", "Los ANGELES", "   CHICAGO"]`), normalize the names by:
#   - Stripping any leading or trailing whitespace.
#   - Converting them to title case (e.g., `"New York"`, `"Los Angeles"`, `"Chicago"`).
# - Ensure that the output is a clean list of city names.

# %%
city_names = ["new york ", "Los ANGELES", "   CHICAGO"]
print(city_names)

messy_location = " new york   "
messy_left = "   Los ANGELES"
messy_right = "CHICAGO   "

print(f"Strip: '{messy_location.strip()}'")
print(f"Lstrip:'{messy_left.lstrip()}'")
print(f"Rstrip:'{messy_right.rstrip()}'")

print(f"Title: '{messy_location.strip().title()}'")
print(f"Title: '{messy_left.lstrip().title()}'")
print(f"Title: '{messy_right.rstrip().title()}'")

Ccity_names = [messy_location.strip().title(), messy_left.lstrip().title(), messy_right.rstrip().title()]
print(Ccity_names)
# Out:
# ['new york ', 'Los ANGELES', '   CHICAGO']
# Strip: 'new york'
# Lstrip:'Los ANGELES'
# Rstrip:'CHICAGO'
# Title: 'New York'
# Title: 'Los Angeles'
# Title: 'Chicago'
# ['New York', 'Los Angeles', 'Chicago']

# %% [markdown]
# ## Exercise 5: Parsing and Extracting Address Information
#
# - Given a string in the format `"Street, City, Country"` (e.g., `"123 Main St, Springfield, USA"`), write a function that parses the string into a dictionary with keys `street`, `city`, and `country`.
# - The function should return a dictionary like `{"street": "123 Main St", "city": "Springfield", "country": "USA"}`.

# %%
address_fullstring = "Andy Holt Tower, Knoxville, USA"
print(address_fullstring)

address_parts = address_fullstring.split(", ")
print(address_parts)

address_dict = {
    "Street": address_parts[0],
    "City": address_parts[1],
    "Country": address_parts[2]
}
print(address_dict)
# Out:
# Andy Holt Tower, Knoxville, USA
# ['Andy Holt Tower', 'Knoxville', 'USA']
# {'Street': 'Andy Holt Tower', 'City': 'Knoxville', 'Country': 'USA'}

# %% [markdown]
# ## Exercise 6: Using For Loops to Process Coordinate Lists
#
# - Create a list of tuples representing coordinates (latitude, longitude).
# - Write a `for` loop that prints each coordinate and indicates whether it is in the Northern or Southern Hemisphere based on the latitude.

# %%
utschools = [
    (35.9541, 83.9311),   #utk
    (35.0469609, -85.2988639), #utc
    (36.3431, -88.8642), #utm
    ]
print("Coordinates of University of TN Schools", utschools)

for lat,lon in utschools:
  print(f"Latitude: {lat}, Longitude: {lon}")
  if lat > 0:
    print("Northern Hemisphere")
  else:
    print("Southern Hemisphere")
# Out:
# Coordinates of University of TN Schools [(35.9541, 83.9311), (35.0469609, -85.2988639), (36.3431, -88.8642)]
# Latitude: 35.9541, Longitude: 83.9311
# Northern Hemisphere
# Latitude: 35.0469609, Longitude: -85.2988639
# Northern Hemisphere
# Latitude: 36.3431, Longitude: -88.8642
# Northern Hemisphere

# %% [markdown]
# ## Exercise 7: While Loops for Iterative Processing
#
# - Create a list of coordinates (latitude, longitude).
# - Write a `while` loop that continues to print each coordinate until it encounters a coordinate with a negative latitude.
# - Stop the loop once this condition is met.

# %%
utskool_coordinates = ['35.9541, 83.9311', '35.0469609, -85.2988639', '36.3431, -88.8642' ]
print(utskool_coordinates)

index = 0
while index < len(utskool_coordinates):
  coordinate = utskool_coordinates[index]
  print(coordinate)
# Out:
# Streaming output truncated to the last 5000 lines.
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# 35.9541, 83.9311
# ...

# %%
limit = 0
while limit > len(utskool_coordinates):
  lat, lon = coordinates[limit]
  print(f"Processing coordinate: ({lat}, {lon})")
  limit += 1
  if lat < 0:
    break

# %% [markdown]
# ## Exercise 8: Conditional Logic in Loops
#
# - Create a list of coordinates and use a `for` loop to iterate over them.
# - Use an `if-elif-else` statement inside the loop to classify each coordinate based on its longitude:
#   - Print `"Eastern Hemisphere"` if the longitude is greater than 0.
#   - Print `"Western Hemisphere"` if the longitude is less than 0.

# %% [markdown]
# ## Exercise 9: Filtering Data with Combined Loops and Conditionals
#
# - Given a list of coordinates, filter out and store only those located in the Southern Hemisphere (latitude < 0).
# - Count the number of coordinates that meet this condition and print the result.

# %% [markdown]
# ## Exercise 10: Generating and Analyzing Random Coordinates
#
# - Write a program that generates random coordinates (latitude between [-90, 90] degrees and longitude between [-180, 180] degrees).
# - Use a `while` loop to keep generating coordinates until a pair with both latitude and longitude greater than 50 is generated.
# - Print each generated coordinate and the final coordinate that meets the condition.
